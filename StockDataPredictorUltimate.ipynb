# %%
import yfinance as yf

# %%
sp500 = yf.Ticker("^GSPC")

# %%
sp500 = sp500.history(period="max")

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2024-04-15 00:00:00-04:00  5149.669922  5168.430176  5052.470215  5061.819824
# 2024-04-16 00:00:00-04:00  5064.589844  5079.839844  5039.830078  5051.410156
# 2024-04-17 00:00:00-04:00  5068.970215  5077.959961  5007.250000  5022.209961
# 2024-04-18 00:00:00-04:00  5031.520020  5056.660156  5001.890137  5011.120117
# 2024-04-19 00:00:00-04:00  5005.439941  5019.020020  4953.560059  4967.229980
#
# ...

# %%
sp500.index
# Out:
# DatetimeIndex(['1927-12-30 00:00:00-05:00', '1928-01-03 00:00:00-05:00',
#                '1928-01-04 00:00:00-05:00', '1928-01-05 00:00:00-05:00',
#                '1928-01-06 00:00:00-05:00', '1928-01-09 00:00:00-05:00',
#                '1928-01-10 00:00:00-05:00', '1928-01-11 00:00:00-05:00',
#                '1928-01-12 00:00:00-05:00', '1928-01-13 00:00:00-05:00',
#                ...
#                '2024-04-08 00:00:00-04:00', '2024-04-09 00:00:00-04:00',
#                '2024-04-10 00:00:00-04:00', '2024-04-11 00:00:00-04:00',
#                '2024-04-12 00:00:00-04:00', '2024-04-15 00:00:00-04:00',
#                '2024-04-16 00:00:00-04:00', '2024-04-17 00:00:00-04:00',
#                '2024-04-18 00:00:00-04:00', '2024-04-19 00:00:00-04:00'],
#               dtype='datetime64[ns, America/New_York]', name='Date', length=24191, freq=None)

# %%
sp500.plot.line(y= "Close", use_index = True)
# Out:
# <Axes: xlabel='Date'>

# %%
del sp500["Dividends"]
del sp500["Stock Splits"]

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2024-04-15 00:00:00-04:00  5149.669922  5168.430176  5052.470215  5061.819824
# 2024-04-16 00:00:00-04:00  5064.589844  5079.839844  5039.830078  5051.410156
# 2024-04-17 00:00:00-04:00  5068.970215  5077.959961  5007.250000  5022.209961
# 2024-04-18 00:00:00-04:00  5031.520020  5056.660156  5001.890137  5011.120117
# 2024-04-19 00:00:00-04:00  5005.439941  5019.020020  4953.560059  4967.229980
#
# ...

# %%
sp500["Tommorow"] = sp500["Close"].shift(-1)

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2024-04-15 00:00:00-04:00  5149.669922  5168.430176  5052.470215  5061.819824
# 2024-04-16 00:00:00-04:00  5064.589844  5079.839844  5039.830078  5051.410156
# 2024-04-17 00:00:00-04:00  5068.970215  5077.959961  5007.250000  5022.209961
# 2024-04-18 00:00:00-04:00  5031.520020  5056.660156  5001.890137  5011.120117
# 2024-04-19 00:00:00-04:00  5005.439941  5019.020020  4953.560059  4967.229980
#
# ...

# %%
sp500["Target"] = (sp500["Tommorow"] > sp500["Close"]).astype(int) #Converting it into int to not proceed to default type -> boolean

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2024-04-15 00:00:00-04:00  5149.669922  5168.430176  5052.470215  5061.819824
# 2024-04-16 00:00:00-04:00  5064.589844  5079.839844  5039.830078  5051.410156
# 2024-04-17 00:00:00-04:00  5068.970215  5077.959961  5007.250000  5022.209961
# 2024-04-18 00:00:00-04:00  5031.520020  5056.660156  5001.890137  5011.120117
# 2024-04-19 00:00:00-04:00  5005.439941  5019.020020  4953.560059  4967.229980
#
# ...

# %%
sp500 = sp500.loc["1999-01-01":].copy()

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1999-01-04 00:00:00-05:00  1229.229980  1248.810059  1219.099976  1228.099976
# 1999-01-05 00:00:00-05:00  1228.099976  1246.109985  1228.099976  1244.780029
# 1999-01-06 00:00:00-05:00  1244.780029  1272.500000  1244.780029  1272.339966
# 1999-01-07 00:00:00-05:00  1272.339966  1272.339966  1257.680054  1269.729980
# 1999-01-08 00:00:00-05:00  1269.729980  1278.239990  1261.819946  1275.089966
# ...                                ...          ...          ...          ...
# 2024-04-15 00:00:00-04:00  5149.669922  5168.430176  5052.470215  5061.819824
# 2024-04-16 00:00:00-04:00  5064.589844  5079.839844  5039.830078  5051.410156
# 2024-04-17 00:00:00-04:00  5068.970215  5077.959961  5007.250000  5022.209961
# 2024-04-18 00:00:00-04:00  5031.520020  5056.660156  5001.890137  5011.120117
# 2024-04-19 00:00:00-04:00  5005.439941  5019.020020  4953.560059  4967.229980
#
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=10000, min_samples_split=80, random_state=1 )

train = sp500.iloc[:-100]
test = sp500.iloc[-100:]

predictors = ["Close", "Volume", "Open", "High", "Low"]
model.fit(train[predictors], train["Target"])
# Out:
# RandomForestClassifier(min_samples_split=80, n_estimators=10000, random_state=1)

# %%
from sklearn.metrics import precision_score #assuming we are buying stock and it decreases

preds = model.predict(test[predictors])

# %%
import pandas as pd

preds = pd.Series(preds, index=test.index)

# %%
precision_score(test["Target"], preds)
# Out:
# 0.6363636363636364

# %%
combined = pd.concat([test["Target"], preds], axis = 1)

# %%
combined.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# Stage 1 completed with precision score of .63%

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["Target"])
    preds = model.predict(test[predictors])
    preds = pd.Series(preds, index=test.index, name="Predictions")
    combined = pd.concat([test["Target"], preds], axis=1)
    return combined

# %%
def backtest(data, model, predictors, start=2500, step=250):
    all_predictions = []

    for i in range(start, data.shape[0], step):
        train = data.iloc[0:i].copy()
        test = data.iloc[i:(i+step)].copy()
        predictions = predict(train, test, predictors, model)
        all_predictions.append(predictions)

    return pd.concat(all_predictions)

# %%
predictions = backtest(sp500, model, predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 1    2018
# 0    1847
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.5292368681863231

# %%
predictions["Target"].value_counts() / predictions.shape[0]
# Out:
# Target
# 1    0.54282
# 0    0.45718
# Name: count, dtype: float64

# %%
horizons = [2,5,60,250,1000]
new_predictors = []

for horizon in horizons:
    rolling_averages = sp500.rolling(horizon).mean()

    ratio_column = f"Close_Ratio_{horizon}"
    sp500[ratio_column] = sp500["Close"] / rolling_averages["Close"]

    trend_column = f"Trend_{horizon}"
    sp500[trend_column] = sp500.shift(1).rolling(horizon).sum()["Target"]

    new_predictors+= [ratio_column, trend_column]

# %%
sp500 = sp500.dropna(subset=sp500.columns[sp500.columns != "Tomorrow"])

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2002-12-26 00:00:00-05:00   892.469971   903.890015   887.479980   889.659973
# 2002-12-27 00:00:00-05:00   889.659973   890.460022   873.619995   875.400024
# 2002-12-30 00:00:00-05:00   875.400024   882.099976   870.229980   879.390015
# 2002-12-31 00:00:00-05:00   879.390015   881.929993   869.450012   879.820007
# 2003-01-02 00:00:00-05:00   879.820007   909.030029   879.820007   909.030029
# ...                                ...          ...          ...          ...
# 2024-04-12 00:00:00-04:00  5171.509766  5175.029785  5107.939941  5123.410156
# 2024-04-15 00:00:00-04:00  5149.669922  5168.430176  5052.470215  5061.819824
# 2024-04-16 00:00:00-04:00  5064.589844  5079.839844  5039.830078  5051.410156
# 2024-04-17 00:00:00-04:00  5068.970215  5077.959961  5007.250000  5022.209961
# 2024-04-18 00:00:00-04:00  5031.520020  5056.660156  5001.890137  5011.120117
#
# ...

# %%
model = RandomForestClassifier(n_estimators=200, min_samples_split=50, random_state=1)

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["Target"])
    preds = model.predict_proba(test[predictors])[:,1]
    preds[preds >=.6] = 1
    preds[preds <.6] = 0
    preds = pd.Series(preds, index=test.index, name="Predictions")
    combined = pd.concat([test["Target"], preds], axis=1)
    return combined

# %%
predictions = backtest(sp500, model, new_predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 0.0    2399
# 1.0     465
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.5182795698924731

# %%
predictions["Target"].value_counts() / predictions.shape[0]
# Out:
# Target
# 1    0.540154
# 0    0.459846
# Name: count, dtype: float64

# %%
predictions
# Out:
#                            Target  Predictions
# Date
# 2012-11-30 00:00:00-05:00       0          0.0
# 2012-12-03 00:00:00-05:00       0          0.0
# 2012-12-04 00:00:00-05:00       1          0.0
# 2012-12-05 00:00:00-05:00       1          0.0
# 2012-12-06 00:00:00-05:00       1          0.0
# ...                           ...          ...
# 2024-04-12 00:00:00-04:00       0          0.0
# 2024-04-15 00:00:00-04:00       0          0.0
# 2024-04-16 00:00:00-04:00       0          0.0
# 2024-04-17 00:00:00-04:00       0          0.0
# 2024-04-18 00:00:00-04:00       0          1.0
#
# [2864 rows x 2 columns]
